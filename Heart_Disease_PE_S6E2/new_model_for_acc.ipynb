# %%
from sklearn.model_selection import StratifiedKFold
import numpy as np
import pandas as pd
from catboost import CatBoostClassifier

# %%
data_test = pd.read_csv('test.csv')
data_train = pd.read_csv('train.csv')

# %% [markdown]
# DATA PREP

# %%
num_cols = ['Age', 'BP', 'Cholesterol', 'Max HR', 'ST depression']
cat_cols = [
    'Sex', 'Chest pain type', 'FBS over 120', 'EKG results',
    'Exercise angina', 'Slope of ST', 'Number of vessels fluro', 'Thallium'
]

# %%
X = data_train.drop(["id", "Heart Disease"], axis = 1)
y = data_train['Heart Disease'].map({'Presence': 1, 'Absence': 0})

# %%
X_test_final = data_test.drop(['id'], axis=1)

# %%
n_splits = 5

# %%
sfk = StratifiedKFold(n_splits = n_splits, shuffle=True, random_state=42)

# %%
oof_preds = np.zeros(len(X))
test_preds = np.zeros(len(X_test_final))
scores = []

# %%
for fold, (train_idx, val_idx) in enumerate(sfk.split(X,y)):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]
    model = CatBoostClassifier(
        n_estimators=8000, 
        learning_rate=0.03,
        depth=6,
        eval_metric='AUC',
        cat_features=cat_cols,
        random_seed=42,
        verbose=100
    )
    model.fit(
        X_train, y_train, 
        eval_set=[(X_val, y_val)], 
        early_stopping_rounds=100
    )
    test_preds += model.predict_proba(X_test_final)[:, 1] / n_splits
    print(f"Fold {fold} completed and predictions accumulated!")
# Out:
# 0:	test: 0.9352988	best: 0.9352988 (0)	total: 331ms	remaining: 44m 8s
# 100:	test: 0.9537225	best: 0.9537225 (100)	total: 14.6s	remaining: 19m 4s
# 200:	test: 0.9545271	best: 0.9545271 (200)	total: 33s	remaining: 21m 20s
# 300:	test: 0.9547884	best: 0.9547884 (300)	total: 50.4s	remaining: 21m 30s
# 400:	test: 0.9549551	best: 0.9549551 (400)	total: 1m 8s	remaining: 21m 37s
# 500:	test: 0.9551313	best: 0.9551313 (500)	total: 1m 27s	remaining: 21m 47s
# 600:	test: 0.9553162	best: 0.9553162 (600)	total: 1m 45s	remaining: 21m 38s
# 700:	test: 0.9554404	best: 0.9554404 (700)	total: 2m 4s	remaining: 21m 31s
# 800:	test: 0.9555267	best: 0.9555267 (800)	total: 2m 21s	remaining: 21m 9s
# 900:	test: 0.9555945	best: 0.9555945 (900)	total: 2m 41s	remaining: 21m 9s
# 1000:	test: 0.9556568	best: 0.9556568 (1000)	total: 3m	remaining: 21m 1s
# 1100:	test: 0.9556990	best: 0.9556991 (1098)	total: 3m 18s	remaining: 20m 42s
# 1200:	test: 0.9557268	best: 0.9557268 (1200)	total: 3m 37s	remaining: 20m 29s
# 1300:	test: 0.9557458	best: 0.9557458 (1300)	total: 3m 56s	remaining: 20m 17s
# 1400:	test: 0.9557582	best: 0.9557585 (1397)	total: 4m 14s	remaining: 19m 56s
# 1500:	test: 0.9557682	best: 0.9557682 (1500)	total: 4m 33s	remaining: 19m 45s
# 1600:	test: 0.9557802	best: 0.9557804 (1599)	total: 4m 53s	remaining: 19m 31s
# 1700:	test: 0.9557867	best: 0.9557867 (1700)	total: 5m 11s	remaining: 19m 14s
# 1800:	test: 0.9558045	best: 0.9558045 (1800)	total: 5m 31s	remaining: 19m 1s
# 1900:	test: 0.9558113	best: 0.9558113 (1900)	total: 5m 53s	remaining: 18m 54s
# 2000:	test: 0.9558139	best: 0.9558144 (1996)	total: 6m 14s	remaining: 18m 43s
# 2100:	test: 0.9558166	best: 0.9558181 (2069)	total: 6m 35s	remaining: 18m 29s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.9558180967
# bestIteration = 2069
#
# Shrink model to first 2070 iterations.
# Fold 0 completed and predictions accumulated!
# 0:	test: 0.9343977	best: 0.9343977 (0)	total: 210ms	remaining: 28m 3s
# 100:	test: 0.9525496	best: 0.9525496 (100)	total: 15.2s	remaining: 19m 50s
# 200:	test: 0.9534961	best: 0.9534961 (200)	total: 31.6s	remaining: 20m 26s
# 300:	test: 0.9537724	best: 0.9537724 (300)	total: 49.3s	remaining: 21m
# 400:	test: 0.9539609	best: 0.9539609 (400)	total: 1m 9s	remaining: 21m 53s
# 500:	test: 0.9541328	best: 0.9541328 (500)	total: 1m 30s	remaining: 22m 31s
# 600:	test: 0.9542967	best: 0.9542967 (600)	total: 1m 51s	remaining: 22m 54s
# 700:	test: 0.9544312	best: 0.9544312 (700)	total: 2m 12s	remaining: 23m
# 800:	test: 0.9545160	best: 0.9545160 (800)	total: 2m 33s	remaining: 22m 57s
# 900:	test: 0.9545816	best: 0.9545816 (900)	total: 2m 52s	remaining: 22m 38s
# 1000:	test: 0.9546325	best: 0.9546325 (1000)	total: 3m 12s	remaining: 22m 24s
# 1100:	test: 0.9546656	best: 0.9546657 (1099)	total: 3m 33s	remaining: 22m 18s
# 1200:	test: 0.9546888	best: 0.9546892 (1199)	total: 3m 56s	remaining: 22m 20s
# 1300:	test: 0.9547124	best: 0.9547126 (1288)	total: 4m 19s	remaining: 22m 14s
# 1400:	test: 0.9547227	best: 0.9547227 (1399)	total: 4m 40s	remaining: 21m 59s
# 1500:	test: 0.9547337	best: 0.9547337 (1500)	total: 4m 58s	remaining: 21m 33s
# 1600:	test: 0.9547410	best: 0.9547410 (1600)	total: 5m 20s	remaining: 21m 22s
# 1700:	test: 0.9547536	best: 0.9547537 (1694)	total: 5m 41s	remaining: 21m 6s
# 1800:	test: 0.9547629	best: 0.9547636 (1794)	total: 6m 1s	remaining: 20m 42s
# 1900:	test: 0.9547663	best: 0.9547674 (1825)	total: 6m 19s	remaining: 20m 16s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.954767425
# bestIteration = 1825
#
# Shrink model to first 1826 iterations.
# Fold 1 completed and predictions accumulated!
# 0:	test: 0.9344088	best: 0.9344088 (0)	total: 204ms	remaining: 27m 8s
# 100:	test: 0.9532338	best: 0.9532338 (100)	total: 16.9s	remaining: 22m 4s
# 200:	test: 0.9542026	best: 0.9542026 (200)	total: 33.1s	remaining: 21m 24s
# 300:	test: 0.9545201	best: 0.9545201 (300)	total: 51.6s	remaining: 22m
# 400:	test: 0.9546894	best: 0.9546895 (399)	total: 1m 9s	remaining: 21m 55s
# 500:	test: 0.9548861	best: 0.9548862 (499)	total: 1m 27s	remaining: 21m 54s
# 600:	test: 0.9550485	best: 0.9550485 (600)	total: 1m 44s	remaining: 21m 24s
# 700:	test: 0.9551493	best: 0.9551494 (699)	total: 2m 3s	remaining: 21m 30s
# 800:	test: 0.9552642	best: 0.9552642 (800)	total: 2m 22s	remaining: 21m 21s
# 900:	test: 0.9553339	best: 0.9553339 (898)	total: 2m 42s	remaining: 21m 17s
# 1000:	test: 0.9553737	best: 0.9553737 (1000)	total: 3m 1s	remaining: 21m 5s
# 1100:	test: 0.9554195	best: 0.9554195 (1100)	total: 3m 20s	remaining: 20m 57s
# 1200:	test: 0.9554561	best: 0.9554563 (1199)	total: 3m 39s	remaining: 20m 40s
# 1300:	test: 0.9554721	best: 0.9554721 (1300)	total: 3m 57s	remaining: 20m 22s
# 1400:	test: 0.9554944	best: 0.9554945 (1399)	total: 4m 17s	remaining: 20m 11s
# 1500:	test: 0.9555143	best: 0.9555143 (1500)	total: 4m 34s	remaining: 19m 48s
# 1600:	test: 0.9555288	best: 0.9555288 (1600)	total: 4m 53s	remaining: 19m 32s
# 1700:	test: 0.9555456	best: 0.9555456 (1700)	total: 5m 16s	remaining: 19m 33s
# 1800:	test: 0.9555567	best: 0.9555568 (1799)	total: 5m 39s	remaining: 19m 28s
# 1900:	test: 0.9555670	best: 0.9555670 (1899)	total: 6m 3s	remaining: 19m 27s
# 2000:	test: 0.9555711	best: 0.9555720 (1979)	total: 6m 24s	remaining: 19m 12s
# 2100:	test: 0.9555769	best: 0.9555777 (2079)	total: 6m 42s	remaining: 18m 50s
# 2200:	test: 0.9555766	best: 0.9555786 (2121)	total: 7m 1s	remaining: 18m 30s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.9555785602
# bestIteration = 2121
#
# Shrink model to first 2122 iterations.
# Fold 2 completed and predictions accumulated!
# 0:	test: 0.9348766	best: 0.9348766 (0)	total: 191ms	remaining: 25m 26s
# 100:	test: 0.9528715	best: 0.9528715 (100)	total: 14.9s	remaining: 19m 23s
# 200:	test: 0.9537822	best: 0.9537822 (200)	total: 32.2s	remaining: 20m 49s
# 300:	test: 0.9540886	best: 0.9540886 (300)	total: 50.6s	remaining: 21m 33s
# 400:	test: 0.9542582	best: 0.9542582 (400)	total: 1m 7s	remaining: 21m 18s
# 500:	test: 0.9543904	best: 0.9543904 (500)	total: 1m 23s	remaining: 20m 52s
# 600:	test: 0.9545373	best: 0.9545373 (600)	total: 1m 39s	remaining: 20m 20s
# 700:	test: 0.9546616	best: 0.9546616 (700)	total: 1m 56s	remaining: 20m 8s
# 800:	test: 0.9547950	best: 0.9547950 (800)	total: 2m 13s	remaining: 20m 1s
# 900:	test: 0.9549044	best: 0.9549044 (900)	total: 2m 30s	remaining: 19m 47s
# 1000:	test: 0.9549619	best: 0.9549620 (999)	total: 2m 47s	remaining: 19m 30s
# 1100:	test: 0.9549983	best: 0.9549983 (1100)	total: 3m 5s	remaining: 19m 19s
# 1200:	test: 0.9550391	best: 0.9550391 (1200)	total: 3m 22s	remaining: 19m 6s
# 1300:	test: 0.9550636	best: 0.9550636 (1300)	total: 3m 40s	remaining: 18m 57s
# 1400:	test: 0.9550850	best: 0.9550850 (1400)	total: 4m 1s	remaining: 18m 55s
# 1500:	test: 0.9551032	best: 0.9551032 (1500)	total: 4m 22s	remaining: 18m 57s
# 1600:	test: 0.9551109	best: 0.9551112 (1597)	total: 4m 43s	remaining: 18m 54s
# 1700:	test: 0.9551174	best: 0.9551187 (1683)	total: 5m 4s	remaining: 18m 46s
# 1800:	test: 0.9551249	best: 0.9551255 (1793)	total: 5m 22s	remaining: 18m 31s
# 1900:	test: 0.9551289	best: 0.9551311 (1835)	total: 5m 42s	remaining: 18m 17s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.9551310923
# bestIteration = 1835
#
# Shrink model to first 1836 iterations.
# Fold 3 completed and predictions accumulated!
# 0:	test: 0.9349122	best: 0.9349122 (0)	total: 197ms	remaining: 26m 18s
# 100:	test: 0.9537065	best: 0.9537065 (100)	total: 15.4s	remaining: 20m 3s
# 200:	test: 0.9545706	best: 0.9545706 (200)	total: 31.6s	remaining: 20m 27s
# 300:	test: 0.9548598	best: 0.9548600 (298)	total: 48.4s	remaining: 20m 39s
# 400:	test: 0.9550031	best: 0.9550031 (400)	total: 1m 4s	remaining: 20m 24s
# 500:	test: 0.9551988	best: 0.9551988 (500)	total: 1m 21s	remaining: 20m 16s
# 600:	test: 0.9553922	best: 0.9553922 (600)	total: 1m 38s	remaining: 20m 8s
# 700:	test: 0.9555023	best: 0.9555023 (699)	total: 1m 55s	remaining: 20m 5s
# 800:	test: 0.9556145	best: 0.9556145 (800)	total: 2m 13s	remaining: 20m 4s
# 900:	test: 0.9556999	best: 0.9556999 (899)	total: 2m 32s	remaining: 19m 58s
# 1000:	test: 0.9557538	best: 0.9557540 (999)	total: 2m 49s	remaining: 19m 47s
# 1100:	test: 0.9557877	best: 0.9557877 (1100)	total: 3m 8s	remaining: 19m 41s
# 1200:	test: 0.9558257	best: 0.9558257 (1198)	total: 3m 26s	remaining: 19m 28s
# 1300:	test: 0.9558667	best: 0.9558667 (1300)	total: 3m 45s	remaining: 19m 19s
# 1400:	test: 0.9558924	best: 0.9558924 (1400)	total: 4m 4s	remaining: 19m 12s
# 1500:	test: 0.9559116	best: 0.9559116 (1500)	total: 4m 23s	remaining: 18m 59s
# 1600:	test: 0.9559295	best: 0.9559299 (1596)	total: 4m 43s	remaining: 18m 54s
# 1700:	test: 0.9559360	best: 0.9559364 (1698)	total: 5m 3s	remaining: 18m 43s
# 1800:	test: 0.9559497	best: 0.9559502 (1795)	total: 5m 22s	remaining: 18m 28s
# 1900:	test: 0.9559609	best: 0.9559612 (1891)	total: 5m 40s	remaining: 18m 12s
# 2000:	test: 0.9559668	best: 0.9559668 (1999)	total: 6m	remaining: 18m 2s
# 2100:	test: 0.9559686	best: 0.9559686 (2100)	total: 6m 19s	remaining: 17m 45s
# 2200:	test: 0.9559717	best: 0.9559721 (2197)	total: 6m 37s	remaining: 17m 27s
# 2300:	test: 0.9559748	best: 0.9559748 (2300)	total: 6m 55s	remaining: 17m 8s
# 2400:	test: 0.9559773	best: 0.9559786 (2380)	total: 7m 13s	remaining: 16m 50s
# 2500:	test: 0.9559809	best: 0.9559810 (2493)	total: 7m 30s	remaining: 16m 30s
# 2600:	test: 0.9559825	best: 0.9559833 (2534)	total: 7m 48s	remaining: 16m 11s
# 2700:	test: 0.9559845	best: 0.9559849 (2687)	total: 8m 5s	remaining: 15m 53s
# 2800:	test: 0.9559857	best: 0.9559867 (2791)	total: 8m 23s	remaining: 15m 34s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.9559866673
# bestIteration = 2791
#
# Shrink model to first 2792 iterations.
# Fold 4 completed and predictions accumulated!

# %%
submission = pd.DataFrame({
    'id': data_test['id'],
    'Heart Disease': test_preds
})

# %%
submission.to_csv('submission2.csv', index=False)

# %%
print(submission.head())
# Out:
#        id  Heart Disease
# 0  630000       0.953485
# 1  630001       0.006801
# 2  630002       0.988663
# 3  630003       0.003895
# 4  630004       0.202500
